# %%
import saxtal_functions as sax
import matplotlib.pyplot as plt
import numpy as np
from itertools import product
from tqdm import tqdm

# %%
movie_filename = 'test_data/test_movie.mrc'
movie_filename_out = 'test_data/test_movie_masked.mrc'
micrograph_filename = 'test_data/test_micrograph.mrc'
micrograph_filename_out = 'test_data/test_micrograph_masked.mrc'
threshold_method='sd' 
pixel_size = 1.45
verbose=True
show_plots=True
threads=16
sigma=15 
num_sd=3.0
num_sd_secondpass=2.0
x_window_percent=(0, 0.7)
y_window_percent=(0, 0.995)
miller_index_buffer=2
box_radius=10
min_lattice_size=5
mask_hotpixels=False
mask_radius=5
replace_distance_percent=0.05
return_spots=True
return_stats=False

# %%
sax.mask_movie(movie_filename,
               movie_filename_out,
               micrograph_filename,
               micrograph_filename_out,
               threshold_method,
               pixel_size,
               verbose=verbose,
               show_plots=show_plots,
               threads=threads,
               sigma=sigma,
               num_sd=num_sd,
               num_sd_secondpass=num_sd_secondpass,
               x_window_percent=x_window_percent,
               y_window_percent=y_window_percent,
               miller_index_buffer=miller_index_buffer,
               box_radius=box_radius,
               min_lattice_size=min_lattice_size,
               mask_hotpixels = mask_hotpixels,
               mask_radius=mask_radius,
               replace_distance_percent=replace_distance_percent,
               return_spots=return_spots,
               return_stats=return_stats)
# Out:
# scipy_batch_fft(): FFT performed in 1116.86 milliseconds.
# scipy_batch_fft(): 37.23 milliseconds per frame.
# scipy_fft(): FFT performed in 47.98 milliseconds.
# Number of first-pass spots found: 85
# Starting basis: [[ 36 -92]
#  [ 93  36]]
# Starting basis size: 19705
# Running basis shortening...
# The angle between the basis vectors is: 89.7906375474851
# [36 93] is larger than [-92  36]
# The updated basis vectors are [128  57][-92  36]
# This run resulted in a basis larger than the last: 29393
# Terminating loop.
# ------------------------------------
# Starting basis: [[ 36 -92]
#  [ 93  36]]
# Refined_basis: [[ 35.79318182 -92.2119697 ]
#  [ 93.03409091  36.32651515]]
# Lattice has less than 5 candidate basis vectors during first pass. Terminating function.
# [[3521.    9.]
#  [3521.   10.]
#  [3521.   11.]
#  ...
#  [3603.  739.]
#  [3603.  740.]
#  [3603.  741.]]
# scipy_inverse_batch_fft(): iFFT performed in 1177.74 milliseconds.
# scipy_inverse_batch_fft(): 39.26 milliseconds per frame.
# Export complete!
# test_data/test_movie.mrc masked successfully!
