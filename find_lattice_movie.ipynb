# %%
import saxtal_functions as sax
import matplotlib.pyplot as plt
import numpy as np
from itertools import product
from tqdm import tqdm

# %%
movie_filename = 'test_data/test_movie.mrc'
movie_filename_out = 'test_data/test_movie_masked.mrc'
micrograph_filename = 'test_data/test_micrograph.mrc'
micrograph_filename_out = 'test_data/test_micrograph_masked.mrc'
threshold_method='sd' 
pixel_size = 1.45
verbose=True
show_plots=True
threads=16
sigma=15 
num_sd=3.0
num_sd_secondpass=2.0
x_window_percent=(0, 0.7)
y_window_percent=(0, 0.995)
miller_index_buffer=2
box_radius=10
min_lattice_size=5
mask_hotpixels=False
mask_radius=5
replace_distance_percent=0.05
return_spots=True
return_stats=False

# %%
sax.mask_movie(movie_filename,
               movie_filename_out,
               micrograph_filename,
               micrograph_filename_out,
               threshold_method,
               pixel_size=pixel_size,
               verbose=verbose,
               show_plots=show_plots,
               threads=threads,
               sigma=sigma,
               num_sd=num_sd,
               num_sd_secondpass=num_sd_secondpass,
               x_window_percent=x_window_percent,
               y_window_percent=y_window_percent,
               miller_index_buffer=miller_index_buffer,
               box_radius=box_radius,
               min_lattice_size=min_lattice_size,
               mask_hotpixels = mask_hotpixels,
               mask_radius=mask_radius,
               replace_distance_percent=replace_distance_percent,
               return_spots=return_spots,
               return_stats=return_stats)
# Out:
# scipy_batch_fft(): FFT performed in 1069.79 milliseconds.
# scipy_batch_fft(): 35.66 milliseconds per frame.
# scipy_fft(): FFT performed in 48.91 milliseconds.
# Number of first-pass spots found: 38
# Starting basis: [[-57  79]
#  [ 82  57]]
# Starting basis size: 19463
# Running basis shortening...
# The angle between the basis vectors is: 88.99284783007197
# [-57  82] is larger than [79 57]
# The updated basis vectors are [-136   25][79 57]
# This run resulted in a basis larger than the last: 28611
# Terminating loop.
# ------------------------------------
# Starting basis: [[-57  79]
#  [ 82  57]]
# Refined_basis: [[-57.25892857  79.36607143]
#  [ 82.02901786  56.81026786]]
# /home/rkarimi/anaconda3/envs/saxtal/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/rkarimi/anaconda3/envs/saxtal/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/rkarimi/anaconda3/envs/saxtal/lib/python3.10/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/rkarimi/anaconda3/envs/saxtal/lib/python3.10/site-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /home/rkarimi/anaconda3/envs/saxtal/lib/python3.10/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# Lattice has less than 5 candidate basis vectors during first pass. Terminating function.
# scipy_inverse_batch_fft(): iFFT performed in 1071.67 milliseconds.
# scipy_inverse_batch_fft(): 35.72 milliseconds per frame.
# Export complete!
# test_data/test_movie_masked.mrc masked successfully!
