# %%
import saxtal_functions as sax
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm, trange
import os
from funcs_mrcio import iwrhdr_opened, irdhdr_opened, iwrsec_opened, irdsec_opened

# %%
threshold_method='sd' 
pixel_size = 1.048
threads=16
sigma=15 
num_sd=3.0
num_sd_secondpass=2.0
x_window_percent=(0.005, 0.7)
y_window_percent=(0, 0.995)
miller_index_buffer=0
box_radius=10
min_lattice_size=8
mask_hotpixels=False
mask_radius=4
replace_distance_percent=0.05
return_spots=False
return_stats=False

# %%
os.chdir('/home/rkarimi/saxtal/pbs-apo_100/')

# %%
micrograph_filenames_in = ["micrograph/" + str(x) for x in os.listdir('micrograph')]
micrograph_filenames_in.sort()

# %%
micrograph_filenames_out = ["micrograph_masked/" + str(x) for x in os.listdir('micrograph')]
micrograph_filenames_out.sort()

# %%
micrograph_filenames_out
# Out:
# ['micrograph_masked/SFO2_101_0015_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_101_0016_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_101_0017_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_101_0018_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_101_0019_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_101_0021_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_101_0022_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_101_0023_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_101_0024_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_101_0025_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_101_0026_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_101_0027_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_101_0028_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_101_0029_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_101_0030_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_101_0031_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_101_0032_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_101_0033_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_101_0034_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_101_0035_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_101_0036_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0001_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0002_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0003_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0004_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0005_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0006_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0007_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0008_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0009_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0010_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0011_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0012_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0013_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0014_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0015_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0016_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0017_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0018_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0019_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0020_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0021_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0022_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0023_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0024_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0025_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0026_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0027_bin2_patch_aligned_doseweighted.mrc',
#  'micrograph_masked/SFO2_102_0028_bin2_patch_aligned_doseweighted.mrc']

# %%
for micrograph_filename_in, micrograph_filename_out in tqdm(zip(micrograph_filenames_in, micrograph_filenames_out)):
    sax.mask_image(micrograph_filename_in,
                   micrograph_filename_out,
                   threshold_method = threshold_method,
                   pixel_size = pixel_size,
                   verbose = False,
                   show_plots = False,
                   threads = threads,
                   sigma = sigma,
                   num_sd = num_sd,
                   num_sd_secondpass = num_sd_secondpass,
                   x_window_percent = x_window_percent,
                   y_window_percent = y_window_percent,
                   miller_index_buffer = miller_index_buffer,
                   box_radius = box_radius,
                   min_lattice_size = min_lattice_size,
                   mask_radius= mask_radius,
                   replace_distance_percent = replace_distance_percent,
                   return_spots = False)
# Out:
# 49it [02:20,  2.86s/it]

# %%
input_filename = "micrograph/SFO2_118_0019_patch_aligned_doseweighted_bin_2.mrc"
output_filename = "micrograph/SFO2_118_0019_patch_aligned_doseweighted_bin_2_masked.mrc"

# %%
sax.mask_image(input_filename,
               output_filename,
               threshold_method = threshold_method,
               pixel_size = pixel_size,
               verbose = True,
               show_plots = True,
               threads = threads,
               sigma = sigma,
               num_sd = num_sd,
               num_sd_secondpass = num_sd_secondpass,
               x_window_percent = x_window_percent,
               y_window_percent = y_window_percent,
               miller_index_buffer = miller_index_buffer,
               box_radius = box_radius,
               min_lattice_size = min_lattice_size,
               mask_radius= mask_radius,
               replace_distance_percent = replace_distance_percent)
# Out:
# scipy_fft(): FFT performed in 90.52 milliseconds.
# Number of first-pass spots found: 121
# Starting basis: [[-54  90]
#  [ 91  54]]
# Starting basis size: 22213
# Running basis shortening...
# The angle between the basis vectors is: 89.72141655752161
# [-54  91] is larger than [90 54]
# The updated basis vectors are [-144   37][90 54]
# This run resulted in a basis larger than the last: 33121
# Terminating loop.
# ------------------------------------
# Starting basis: [[-54  90]
#  [ 91  54]]
# Refined_basis: [[-53.78328249  89.7862111 ]
#  [ 91.26174497  54.2147651 ]]
# /home/rkarimi/anaconda3/envs/saxtal/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/rkarimi/anaconda3/envs/saxtal/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/rkarimi/anaconda3/envs/saxtal/lib/python3.10/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/rkarimi/anaconda3/envs/saxtal/lib/python3.10/site-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /home/rkarimi/anaconda3/envs/saxtal/lib/python3.10/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/rkarimi/saxtal/saxtal_functions.py:243: RuntimeWarning: invalid value encountered in arccos
#   angle = (360/(2*np.pi))*np.arccos(np.dot(basis_matrix[:,0], basis_matrix[:,1])/
# Lattice has less than 8 candidate basis vectors during first pass. Terminating function.
# scipy_ifft(): iFFT performed in 70.7 milliseconds.
# Export complete!
# micrograph/SFO2_118_0019_patch_aligned_doseweighted_bin_2.mrc masked successfully!
